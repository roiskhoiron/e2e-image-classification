# %% [markdown]
# # Data Ingestion & Validation
#
# This notebook demonstrates downloading a public image dataset, validating image files, and splitting the data into train/val/test directories.

# %%
from src.data.dataset_builder import run_ingestion
run_ingestion()
